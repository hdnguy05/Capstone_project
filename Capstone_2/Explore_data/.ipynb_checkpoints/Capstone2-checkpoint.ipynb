# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import datetime

# %%
data = pd.read_csv('data/movies_metadata.csv', low_memory =False)

# %%
#data_credit = pd.read_csv('data/credits.csv')

# %%
data.head().T
# Out:
#                                                                        0  \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
# id                                                                   862
# imdb_id                                                        tt0114709
# original_language                                                     en
# original_title                                                 Toy Story
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                     21.946943
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# production_companies      [{'name': 'Pixar Animation Studios', 'id': 3}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-10-30
# revenue                                                      3.73554e+08
# runtime                                                               81
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                          Toy Story
# video                                                              False
# vote_average                                                         7.7
# vote_count                                                          5415
#
#                                                                        1  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                             NaN
# id                                                                  8844
# imdb_id                                                        tt0113497
# original_language                                                     en
# original_title                                                   Jumanji
# overview               When siblings Judy and Peter discover an encha...
# popularity                                                     17.015539
# poster_path                             /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# production_companies   [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-15
# revenue                                                      2.62797e+08
# runtime                                                              104
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                        Roll the dice and unleash the excitement!
# title                                                            Jumanji
# video                                                              False
# vote_average                                                         6.9
# vote_count                                                          2413
#
#                                                                        2  \
# adult                                                              False
# belongs_to_collection  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                 0
# genres                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                             NaN
# id                                                                 15602
# imdb_id                                                        tt0113228
# original_language                                                     en
# original_title                                          Grumpier Old Men
# overview               A family wedding reignites the ancient feud be...
# popularity                                                       11.7129
# poster_path                             /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                                0
# runtime                                                              101
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# video                                                              False
# vote_average                                                         6.5
# vote_count                                                            92
#
#                                                                        3  \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          16000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                                             NaN
# id                                                                 31357
# imdb_id                                                        tt0114885
# original_language                                                     en
# original_title                                         Waiting to Exhale
# overview               Cheated on, mistreated and stepped on, the wom...
# popularity                                                      3.859495
# poster_path                             /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# production_companies   [{'name': 'Twentieth Century Fox Film Corporat...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-12-22
# revenue                                                      8.14522e+07
# runtime                                                              127
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Friends are the people who let you be yourself...
# title                                                  Waiting to Exhale
# video                                                              False
# vote_average                                                         6.1
# vote_count                                                            34
#
#                                                                        4
# adult                                                              False
# belongs_to_collection  {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                 0
# genres                                    [{'id': 35, 'name': 'Comedy'}]
# homepage                                                             NaN
# id                                                                 11862
# imdb_id                                                        tt0113041
# original_language                                                     en
# original_title                               Father of the Bride Part II
# overview               Just when George Banks has recovered from his ...
# popularity                                                      8.387519
# poster_path                             /e64sOI48hQXyru7naBFyssKFxVd.jpg
# production_companies   [{'name': 'Sandollar Productions', 'id': 5842}...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1995-02-10
# revenue                                                      7.65789e+07
# runtime                                                              106
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Just When His World Is Back To Normal... He's ...
# title                                        Father of the Bride Part II
# video                                                              False
# vote_average                                                         5.7
# vote_count                                                           173

# %%
##Inspecting the data. So you can see that have 20 column is object and 4 column is float64
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
### Need to convert column to number
## budget, id, popularity
## and convert release data to datetime
data['id'] = pd.to_numeric(data['id'], errors= 'coerce')

# %%
data[data['id'].isnull()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage  id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso... NaN       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o... NaN       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}] NaN       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
# 29503  ...           12     NaN     NaN              NaN    NaN      NaN
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
# 29503    NaN   NaN          NaN        NaN
# 35587    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
### this 3 row are have wierd format so just remove it 
data.drop([19730,29503,35587], axis = 0, inplace = True)
data = data.reset_index()

# %%
### we have 24 column, with 20 column are object and 4 column are float
### For these column we doesnt need for our data. Like homepage just website of that movie
##Adult mean it x-rate or adult rate
##original_title was when the movie make, but we have the version engligh in title
drop_columns = ['homepage','adult','original_title']
data.drop(drop_columns, axis = 1, inplace = True)

# %%
## COunt missing value
## Get total how many missing value in each column
data.isna().sum().sort_values(ascending = False)
# Out:
# belongs_to_collection    40972
# tagline                  25051
# overview                   954
# poster_path                386
# runtime                    260
# release_date                87
# status                      84
# imdb_id                     17
# original_language           11
# vote_count                   3
# popularity                   3
# production_companies         3
# vote_average                 3
# production_countries         3
# revenue                      3
# spoken_languages             3
# title                        3
# video                        3
# id                           0
# genres                       0
# budget                       0
# index                        0
# dtype: int64

# %%
## As you know that column: belong_to_collection, spoken_languages, production_countries, production_company are
## format as a string of a list of dictionaries
## So we know dictionaries have key word 'name' and 'id'. But we only interest in the name
## Each column have missing value so we cant apply with our function
## We need to fill nan with a default assign None to the 'name' of dictionaries

##Fill the missing with the name missing_name
data['belongs_to_collection'].fillna(str({'name': None}), inplace =True)
data['spoken_languages'].fillna(str([{'name': None}]), inplace =True)
data['production_countries'].fillna(str([{'name': None}]), inplace =True)
data['production_companies'].fillna(str([{'name': None}]), inplace =True)

# %%
##Convert genres to only genres name
## eval() function to convert to string of list to a list '[1,2,3]' = [1,2,3]
def convert_object_to_list(data):
    data = eval(data)
    empty = []
    if type(data) == bool or type(data) == float or type(data) == int:
        return None
    else:
        for z in data:
            empty.append(z['name'])
    return empty

## Convert belong to to name
def convert_belongcolumn_to_list(data):
    data = eval(data)
    if type(data) == float or type(data) == int:
        return None
    else:
        return data['name']
    
#Convert the Countried to COuntried name    
def convert_countries_name(data):
    data = eval(data)
    empty = []
    if type(data) == bool or type(data) == float or type(data) == int:
        return None
    else:
        for z in data:
            return z['name']

# %%
## Convert the columtype object to the list of name desires
data['genres']= data['genres'].apply(convert_object_to_list)
data['production_companies'] = data['production_companies'].apply(convert_object_to_list)
data['production_countries'] = data['production_countries'].apply(convert_countries_name)
data['spoken_languages'] = data['spoken_languages'].apply(convert_countries_name)
data['belongs_to_collection'] = data['belongs_to_collection'].apply(convert_belongcolumn_to_list)

# %%
data.isna().sum().sort_values(ascending = False)
# Out:
# belongs_to_collection    40972
# tagline                  25051
# production_countries      6285
# spoken_languages          3832
# overview                   954
# poster_path                386
# runtime                    260
# release_date                87
# status                      84
# imdb_id                     17
# original_language           11
# revenue                      3
# vote_average                 3
# title                        3
# popularity                   3
# video                        3
# vote_count                   3
# budget                       0
# production_companies         0
# genres                       0
# id                           0
# index                        0
# dtype: int64

# %%
## convert the budget to the number and have alot budget was 0 so we need to replace it with nan
data['budget'] = pd.to_numeric(data['budget'], errors='coerce')

# %%
### Let see how many budget was 0.
## If budget 0 it mean we dont have any data above budget for that movie
data[data.budget == 0].budget.count()
# Out:
# 36573

# %%
## the same let checking if revenue
data[data.revenue == 0].revenue.count()
# Out:
# 38052

# %%
## The missing the budget and revenue are not same
## S0 you can tell that we cant not base one that to calculation the profit
## if we want see which movie are have more profit, so we look at ratio revenue/bubget
## but we cant not divide for 0, so we replace 0 with np.nan
data['budget'] = data['budget'].replace(0, np.nan)
data['revenue'] = data['revenue'].replace(0, np.nan)

# %%
### Created a new column for data name ratio_revenue
data['ratio_revenue'] = data['revenue'] / data['budget']

# %%
##Let make another column for total the number company are was make a movie
### Get the max number in in movie
### maybe add new column in later for total company
number_company = []
for i in data.production_companies:
    try:
        number_company.append(len(i))   
    except:
        print(i) ## point where is error

# %%
data['number_company'] = number_company

# %%
##Return column (revenue - budget)
data['return'] = data['revenue'] - data['budget']

# %%
### checking how many data we doesnt have information above company make
data.number_company
# Out:
# 0        1
# 1        3
# 2        2
# 3        1
# 4        2
#         ..
# 45458    0
# 45459    1
# 45460    1
# 45461    1
# 45462    0
# Name: number_company, Length: 45463, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
# index                    45463 non-null int64
# belongs_to_collection    4491 non-null object
# budget                   8890 non-null float64
# genres                   45463 non-null object
# id                       45463 non-null float64
# imdb_id                  45446 non-null object
# original_language        45452 non-null object
# overview                 44509 non-null object
# popularity               45460 non-null object
# poster_path              45077 non-null object
# production_companies     45463 non-null object
# production_countries     39178 non-null object
# release_date             45376 non-null object
# revenue                  7408 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         41631 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# ratio_revenue            5381 non-null float64
# number_company           45463 non-null int64
# dtypes: float64(7), int64(2), object(15)
# memory usage: 8.3+ MB

# %%
### get df for only movie have information above budget and revenue
df_ratio_revenue = data[~data['ratio_revenue'].isnull()]

# %%
df_ratio_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5381 entries, 0 to 45419
# Data columns (total 24 columns):
# index                    5381 non-null int64
# belongs_to_collection    1224 non-null object
# budget                   5381 non-null float64
# genres                   5381 non-null object
# id                       5381 non-null float64
# imdb_id                  5381 non-null object
# original_language        5381 non-null object
# overview                 5370 non-null object
# popularity               5381 non-null object
# poster_path              5381 non-null object
# production_companies     5381 non-null object
# production_countries     5320 non-null object
# release_date             5381 non-null object
# revenue                  5381 non-null float64
# runtime                  5380 non-null float64
# spoken_languages         5358 non-null object
# status                   5381 non-null object
# tagline                  4629 non-null object
# title                    5381 non-null object
# video                    5381 non-null object
# vote_average             5381 non-null float64
# vote_count               5381 non-null float64
# ratio_revenue            5381 non-null float64
# number_company           5381 non-null int64
# dtypes: float64(7), int64(2), object(15)
# memory usage: 1.0+ MB

# %%
data['popularity'] = pd.to_numeric(data['popularity'], errors='coerce')
data['popularity'] = data['popularity'].replace(0, np.nan)

# %%
collection_name = data.belongs_to_collection.fillna('')
collection_name = ' '.join(collection_name)

# %%
Collection_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', height=2000, width=4000).generate(collection_name)
plt.figure(figsize=(16,8))
plt.imshow(Collection_wordcloud)
plt.axis('off')
plt.show()

# %%
#### See the each countries make how many film and profit did they got
movies_countries = data.groupby(['production_countries']).agg({'return':['mean','sum','count']})
movies_countries.columns = ['average_return','total_return','number_movie']
movies_countries.sort_values(by = 'number_movie', ascending = False, inplace = True)

# %%
### Average profit of each countries
average_return = movies_countries[['average_return']][0:15]
average_return.sort_values(by = 'average_return', ascending = False, inplace = True)
_ = plt.figure(figsize = (15,5))
_ = sns.barplot(x = average_return.index, y = average_return.average_return)
_ = plt.title('AVERAGE PROFIT OF EACH COUNTRIES')
_ = plt.xticks(rotation = 30)

# %%
average_return = movies_countries[['total_return']][0:15]
average_return.sort_values(by = 'total_return', ascending = False, inplace = True)
_ = plt.figure(figsize = (15,5))
_ = sns.barplot(x = average_return.index, y = average_return.average_return)
_ = plt.xticks(rotation = 30)

# %%
### Count number movie of each company production
company_name = pd.Series(np.concatenate(data.production_companies))
number_movie = company_name.value_counts()
number_movie[0:10]
# Out:
# Warner Bros.                              1250
# Metro-Goldwyn-Mayer (MGM)                 1076
# Paramount Pictures                        1003
# Twentieth Century Fox Film Corporation     836
# Universal Pictures                         830
# Columbia Pictures Corporation              448
# Canal+                                     438
# Columbia Pictures                          431
# RKO Radio Pictures                         290
# United Artists                             279
# dtype: int64

# %%
plt.xlabel
